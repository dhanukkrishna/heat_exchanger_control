# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from collections import deque

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print("Using device:", device)
# Out:
# Using device: cpu

# %%
# PHYSICAL PROPERTIES (WATER)


rho = 997.0
cp = 4180.0
k = 0.63
mu = 0.000653


# HEAT EXCHANGER GEOMETRY

D = 0.02
L = 20.0

A_heat = np.pi * D * L

# PROCESS CONDITIONS

T_cold_in = 25.0
T_target = 55.0

m_dot_cold = 0.30

# ACTION SPACE

actions = np.array([
    -0.05,
    -0.02,
    -0.01,
     0.00,
     0.01,
     0.02,
     0.05
])

n_actions = len(actions)

# DQN HYPERPARAMETERS

gamma = 0.95

epsilon = 1.0
epsilon_decay = 0.995
epsilon_min = 0.01

learning_rate = 0.001

batch_size = 64

memory_size = 10000

episodes = 3000

# %%
# REPLAY MEMORY

memory = deque(maxlen=memory_size)

# %%
# HEAT EXCHANGER MODEL

def hx_model(m_dot_hot, T_hot_in):

    m_dot_hot = max(m_dot_hot, 0.05)

    A_flow = np.pi * (D / 2)**2

    V = m_dot_hot / (rho * A_flow)

    Re = rho * V * D / mu

    Re = max(Re, 3000)

    Pr = cp * mu / k

    Nu = 0.023 * Re**0.8 * Pr**0.4

    h = Nu * k / D

    U = 0.9 * h

    # Capacity rates
    C_hot = m_dot_hot * cp
    C_cold = m_dot_cold * cp

    C_min = min(C_hot, C_cold)
    C_max = max(C_hot, C_cold)

    Cr = C_min / C_max

    # NTU
    NTU = U * A_heat / C_min

    # STABLE EFFECTIVENESS

    if abs(Cr - 1.0) < 1e-6:

        eps = NTU / (1 + NTU)

    else:

        numerator = (
            1 - np.exp(-NTU * (1 - Cr))
        )

        denominator = (
            1 - Cr * np.exp(-NTU * (1 - Cr))
        )

        eps = numerator / denominator

    eps = np.clip(eps, 0, 1)

    # Heat transfer
    Qdot = eps * C_min * (
        T_hot_in - T_cold_in
    )

    # Outlet temperature
    T_hot_out = T_hot_in - Qdot / C_hot

    # Numerical safety
    if np.isnan(T_hot_out):
        T_hot_out = T_hot_in

    return T_hot_out

# %%
# PRESSURE DROP MODEL

def pressure_drop(m_dot):

    m_dot = max(m_dot, 0.05)

    A_flow = np.pi * (D / 2)**2

    V = m_dot / (rho * A_flow)

    Re = rho * V * D / mu

    Re = max(Re, 3000)

    f = 0.316 * Re**(-0.25)

    dP = f * (L / D) * (
        rho * V**2 / 2
    )

    return dP

# %%
# STATE VECTOR

def get_state(T_out, m_dot, T_hot_in):

    return np.array([

        T_out / 100,

        m_dot / 1.0,

        T_hot_in / 100

    ], dtype=np.float32)

# %%
# DQN NETWORK

class DQN(nn.Module):

    def __init__(self):

        super(DQN, self).__init__()

        self.network = nn.Sequential(

            nn.Linear(3, 64),
            nn.ReLU(),

            nn.Linear(64, 64),
            nn.ReLU(),

            nn.Linear(64, n_actions)

        )

    def forward(self, x):

        return self.network(x)

# %%
# CREATE NETWORK

model = DQN().to(device)

optimizer = optim.Adam(
    model.parameters(),
    lr=learning_rate
)

criterion = nn.MSELoss()

print(model)
# Out:
# DQN(
#   (network): Sequential(
#     (0): Linear(in_features=3, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=7, bias=True)
#   )
# )

# %%
# ACTION SELECTION

def select_action(state, epsilon):

    if random.random() < epsilon:

        return random.randint(
            0,
            n_actions - 1
        )

    state_tensor = torch.FloatTensor(
        state
    ).unsqueeze(0).to(device)

    with torch.no_grad():

        q_values = model(state_tensor)

    return torch.argmax(q_values).item()

# %%
# STORE EXPERIENCE

def store_experience(
    state,
    action,
    reward,
    next_state,
    done
):

    memory.append((
        state,
        action,
        reward,
        next_state,
        done
    ))

# %%
# TRAIN DQN

def train_dqn():

    if len(memory) < batch_size:
        return

    batch = random.sample(
        memory,
        batch_size
    )

    states = np.array([
        x[0] for x in batch
    ])

    actions_batch = np.array([
        x[1] for x in batch
    ])

    rewards = np.array([
        x[2] for x in batch
    ])

    next_states = np.array([
        x[3] for x in batch
    ])

    dones = np.array([
        x[4] for x in batch
    ])

    # Convert to tensors
    states = torch.FloatTensor(
        states
    ).to(device)

    actions_batch = torch.LongTensor(
        actions_batch
    ).to(device)

    rewards = torch.FloatTensor(
        rewards
    ).to(device)

    next_states = torch.FloatTensor(
        next_states
    ).to(device)

    dones = torch.FloatTensor(
        dones
    ).to(device)

    # Current Q values
    q_values = model(states)

    current_q = q_values.gather(
        1,
        actions_batch.unsqueeze(1)
    ).squeeze()

    # Next Q values
    with torch.no_grad():

        next_q = model(next_states)

        max_next_q = torch.max(
            next_q,
            dim=1
        )[0]

    # Bellman target
    target_q = rewards + gamma * max_next_q * (1 - dones)

    # Loss
    loss = criterion(
        current_q,
        target_q
    )

    # Backpropagation
    optimizer.zero_grad()

    loss.backward()

    optimizer.step()

# %%
# DQN TRAINING LOOP

reward_history = []

for episode in range(episodes):

    # Initial Conditions

    T_hot_in = 80.0

    m_dot = 0.50

    total_reward = 0

    # Initial outlet temperature
    T_out = hx_model(
        m_dot,
        T_hot_in
    )

    state = get_state(
        T_out,
        m_dot,
        T_hot_in
    )

    # TIME LOOP

    for step in range(200):

        # Disturbance
        if step > 100:
            T_hot_in = 70.0

        # SELECT ACTION

        action_index = select_action(
            state,
            epsilon
        )

        action = actions[action_index]

        # APPLY ACTION

        m_dot_new = m_dot + action

        m_dot_new = np.clip(
            m_dot_new,
            0.05,
            1.0
        )

        # NEW SYSTEM RESPONSE

        T_out_new = hx_model(
            m_dot_new,
            T_hot_in
        )

        dP_new = pressure_drop(
            m_dot_new
        )

        next_state = get_state(
            T_out_new,
            m_dot_new,
            T_hot_in
        )

        # REWARD FUNCTION

        temp_error = abs(
            T_target - T_out_new
        )

        reward = (
            -5 * temp_error**2
            -0.00003 * dP_new
            -0.02 * abs(action)
        )

        # Extra penalty
        if temp_error > 5:
            reward -= 100

        done = False

        # STORE EXPERIENCE

        store_experience(
            state,
            action_index,
            reward,
            next_state,
            done
        )

        # TRAIN NETWORK

        train_dqn()

        # Update state
        state = next_state

        m_dot = m_dot_new

        total_reward += reward

    # EPSILON DECAY

    epsilon = max(
        epsilon_min,
        epsilon * epsilon_decay
    )

    reward_history.append(
        total_reward
    )

    # Print progress
    if episode % 10 == 0:

        print(
            f"Episode {episode}"
            f" | Reward = {total_reward:.2f}"
            f" | Epsilon = {epsilon:.3f}"
        )
# Out:
# Episode 0 | Reward = -792253.19 | Epsilon = 0.995
# Episode 10 | Reward = -20348.06 | Epsilon = 0.946
# Episode 20 | Reward = -15528.50 | Epsilon = 0.900
# Episode 30 | Reward = -140265.07 | Epsilon = 0.856
# Episode 40 | Reward = -26902.60 | Epsilon = 0.814
# Episode 50 | Reward = -19056.35 | Epsilon = 0.774
# Episode 60 | Reward = -21775.18 | Epsilon = 0.737
# Episode 70 | Reward = -11342.40 | Epsilon = 0.701
# Episode 80 | Reward = -13139.70 | Epsilon = 0.666
# Episode 90 | Reward = -10468.03 | Epsilon = 0.634
# Episode 100 | Reward = -8418.02 | Epsilon = 0.603
# Episode 110 | Reward = -14909.47 | Epsilon = 0.573
# Episode 120 | Reward = -10153.95 | Epsilon = 0.545
# Episode 130 | Reward = -9640.93 | Epsilon = 0.519
# Episode 140 | Reward = -8153.33 | Epsilon = 0.493
# Episode 150 | Reward = -5881.07 | Epsilon = 0.469
# Episode 160 | Reward = -6495.11 | Epsilon = 0.446
# Episode 170 | Reward = -3118.91 | Epsilon = 0.424
# Episode 180 | Reward = -3118.75 | Epsilon = 0.404
# Episode 190 | Reward = -1953.05 | Epsilon = 0.384
# Episode 200 | Reward = -3132.07 | Epsilon = 0.365
# Episode 210 | Reward = -1619.22 | Epsilon = 0.347
# Episode 220 | Reward = -1909.92 | Epsilon = 0.330
# Episode 230 | Reward = -1580.03 | Epsilon = 0.314
# Episode 240 | Reward = -1422.58 | Epsilon = 0.299
# Episode 250 | Reward = -2088.24 | Epsilon = 0.284
# Episode 260 | Reward = -1511.92 | Epsilon = 0.270
# Episode 270 | Reward = -1865.43 | Epsilon = 0.257
# Episode 280 | Reward = -1521.27 | Epsilon = 0.245
# Episode 290 | Reward = -1452.85 | Epsilon = 0.233
# Episode 300 | Reward = -1238.50 | Epsilon = 0.221
# Episode 310 | Reward = -1248.08 | Epsilon = 0.210
# Episode 320 | Reward = -978.93 | Epsilon = 0.200
# Episode 330 | Reward = -1676.73 | Epsilon = 0.190
# Episode 340 | Reward = -1344.45 | Epsilon = 0.181
# Episode 350 | Reward = -965.84 | Epsilon = 0.172
# Episode 360 | Reward = -1141.73 | Epsilon = 0.164
# Episode 370 | Reward = -1439.54 | Epsilon = 0.156
# Episode 380 | Reward = -838.05 | Epsilon = 0.148
# Episode 390 | Reward = -1695.27 | Epsilon = 0.141
# Episode 400 | Reward = -1358.56 | Epsilon = 0.134
# Episode 410 | Reward = -1256.15 | Epsilon = 0.127
# Episode 420 | Reward = -1143.30 | Epsilon = 0.121
# Episode 430 | Reward = -1150.35 | Epsilon = 0.115
# Episode 440 | Reward = -1331.21 | Epsilon = 0.110
# Episode 450 | Reward = -1073.38 | Epsilon = 0.104
# Episode 460 | Reward = -1967.50 | Epsilon = 0.099
# Episode 470 | Reward = -1058.52 | Epsilon = 0.094
# Episode 480 | Reward = -1226.58 | Epsilon = 0.090
# Episode 490 | Reward = -996.79 | Epsilon = 0.085
# Episode 500 | Reward = -1052.41 | Epsilon = 0.081
# Episode 510 | Reward = -1429.31 | Epsilon = 0.077
# Episode 520 | Reward = -958.87 | Epsilon = 0.073
# Episode 530 | Reward = -1005.52 | Epsilon = 0.070
# Episode 540 | Reward = -917.16 | Epsilon = 0.066
# Episode 550 | Reward = -1101.97 | Epsilon = 0.063
# Episode 560 | Reward = -860.34 | Epsilon = 0.060
# Episode 570 | Reward = -902.32 | Epsilon = 0.057
# Episode 580 | Reward = -971.64 | Epsilon = 0.054
# Episode 590 | Reward = -1084.20 | Epsilon = 0.052
# Episode 600 | Reward = -1019.68 | Epsilon = 0.049
# Episode 610 | Reward = -978.75 | Epsilon = 0.047
# Episode 620 | Reward = -949.13 | Epsilon = 0.044
# Episode 630 | Reward = -1127.84 | Epsilon = 0.042
# Episode 640 | Reward = -931.46 | Epsilon = 0.040
# Episode 650 | Reward = -1408.13 | Epsilon = 0.038
# Episode 660 | Reward = -983.14 | Epsilon = 0.036
# Episode 670 | Reward = -974.83 | Epsilon = 0.035
# Episode 680 | Reward = -1267.24 | Epsilon = 0.033
# Episode 690 | Reward = -1062.12 | Epsilon = 0.031
# Episode 700 | Reward = -1099.19 | Epsilon = 0.030
# Episode 710 | Reward = -1038.84 | Epsilon = 0.028
# Episode 720 | Reward = -1089.93 | Epsilon = 0.027
# Episode 730 | Reward = -1109.00 | Epsilon = 0.026
# Episode 740 | Reward = -1008.34 | Epsilon = 0.024
# Episode 750 | Reward = -870.90 | Epsilon = 0.023
# Episode 760 | Reward = -958.92 | Epsilon = 0.022
# Episode 770 | Reward = -886.02 | Epsilon = 0.021
# Episode 780 | Reward = -955.84 | Epsilon = 0.020
# Episode 790 | Reward = -985.90 | Epsilon = 0.019
# Episode 800 | Reward = -964.21 | Epsilon = 0.018
# Episode 810 | Reward = -1006.77 | Epsilon = 0.017
# Episode 820 | Reward = -976.00 | Epsilon = 0.016
# Episode 830 | Reward = -968.80 | Epsilon = 0.016
# Episode 840 | Reward = -1025.87 | Epsilon = 0.015
# Episode 850 | Reward = -1210.58 | Epsilon = 0.014
# Episode 860 | Reward = -919.25 | Epsilon = 0.013
# Episode 870 | Reward = -1020.15 | Epsilon = 0.013
# Episode 880 | Reward = -971.95 | Epsilon = 0.012
# Episode 890 | Reward = -1087.26 | Epsilon = 0.011
# Episode 900 | Reward = -943.78 | Epsilon = 0.011
# Episode 910 | Reward = -973.35 | Epsilon = 0.010
# Episode 920 | Reward = -958.31 | Epsilon = 0.010
# Episode 930 | Reward = -993.83 | Epsilon = 0.010
# Episode 940 | Reward = -1023.79 | Epsilon = 0.010
# Episode 950 | Reward = -1229.72 | Epsilon = 0.010
# Episode 960 | Reward = -997.23 | Epsilon = 0.010
# Episode 970 | Reward = -883.90 | Epsilon = 0.010
# Episode 980 | Reward = -910.88 | Epsilon = 0.010
# Episode 990 | Reward = -1327.26 | Epsilon = 0.010
# Episode 1000 | Reward = -1010.53 | Epsilon = 0.010
# Episode 1010 | Reward = -880.88 | Epsilon = 0.010
# Episode 1020 | Reward = -1092.46 | Epsilon = 0.010
# Episode 1030 | Reward = -937.26 | Epsilon = 0.010
# Episode 1040 | Reward = -922.96 | Epsilon = 0.010
# Episode 1050 | Reward = -846.73 | Epsilon = 0.010
# Episode 1060 | Reward = -903.77 | Epsilon = 0.010
# Episode 1070 | Reward = -931.43 | Epsilon = 0.010
# Episode 1080 | Reward = -941.60 | Epsilon = 0.010
# Episode 1090 | Reward = -938.48 | Epsilon = 0.010
# Episode 1100 | Reward = -965.30 | Epsilon = 0.010
# Episode 1110 | Reward = -904.02 | Epsilon = 0.010
# Episode 1120 | Reward = -915.15 | Epsilon = 0.010
# Episode 1130 | Reward = -1148.82 | Epsilon = 0.010
# Episode 1140 | Reward = -985.08 | Epsilon = 0.010
# Episode 1150 | Reward = -981.57 | Epsilon = 0.010
# Episode 1160 | Reward = -903.54 | Epsilon = 0.010
# Episode 1170 | Reward = -1004.38 | Epsilon = 0.010
# Episode 1180 | Reward = -905.87 | Epsilon = 0.010
# Episode 1190 | Reward = -985.37 | Epsilon = 0.010
# Episode 1200 | Reward = -1000.72 | Epsilon = 0.010
# Episode 1210 | Reward = -936.49 | Epsilon = 0.010
# Episode 1220 | Reward = -900.39 | Epsilon = 0.010
# Episode 1230 | Reward = -1025.58 | Epsilon = 0.010
# Episode 1240 | Reward = -992.67 | Epsilon = 0.010
# Episode 1250 | Reward = -935.93 | Epsilon = 0.010
# Episode 1260 | Reward = -902.70 | Epsilon = 0.010
# Episode 1270 | Reward = -894.81 | Epsilon = 0.010
# Episode 1280 | Reward = -978.82 | Epsilon = 0.010
# Episode 1290 | Reward = -923.14 | Epsilon = 0.010
# Episode 1300 | Reward = -1094.62 | Epsilon = 0.010
# Episode 1310 | Reward = -912.92 | Epsilon = 0.010
# Episode 1320 | Reward = -1065.75 | Epsilon = 0.010
# Episode 1330 | Reward = -943.04 | Epsilon = 0.010
# Episode 1340 | Reward = -1487.37 | Epsilon = 0.010
# Episode 1350 | Reward = -921.74 | Epsilon = 0.010
# Episode 1360 | Reward = -885.57 | Epsilon = 0.010
# Episode 1370 | Reward = -889.30 | Epsilon = 0.010
# Episode 1380 | Reward = -977.83 | Epsilon = 0.010
# Episode 1390 | Reward = -967.63 | Epsilon = 0.010
# Episode 1400 | Reward = -917.91 | Epsilon = 0.010
# Episode 1410 | Reward = -932.38 | Epsilon = 0.010
# Episode 1420 | Reward = -828.52 | Epsilon = 0.010
# Episode 1430 | Reward = -962.90 | Epsilon = 0.010
# Episode 1440 | Reward = -906.01 | Epsilon = 0.010
# Episode 1450 | Reward = -1009.31 | Epsilon = 0.010
# Episode 1460 | Reward = -942.54 | Epsilon = 0.010
# Episode 1470 | Reward = -883.36 | Epsilon = 0.010
# Episode 1480 | Reward = -937.35 | Epsilon = 0.010
# Episode 1490 | Reward = -919.18 | Epsilon = 0.010
# Episode 1500 | Reward = -977.21 | Epsilon = 0.010
# Episode 1510 | Reward = -912.09 | Epsilon = 0.010
# Episode 1520 | Reward = -930.40 | Epsilon = 0.010
# Episode 1530 | Reward = -962.22 | Epsilon = 0.010
# Episode 1540 | Reward = -1044.59 | Epsilon = 0.010
# Episode 1550 | Reward = -1063.64 | Epsilon = 0.010
# Episode 1560 | Reward = -1024.66 | Epsilon = 0.010
# Episode 1570 | Reward = -969.19 | Epsilon = 0.010
# Episode 1580 | Reward = -1109.00 | Epsilon = 0.010
# Episode 1590 | Reward = -980.77 | Epsilon = 0.010
# Episode 1600 | Reward = -976.55 | Epsilon = 0.010
# Episode 1610 | Reward = -929.94 | Epsilon = 0.010
# Episode 1620 | Reward = -819.83 | Epsilon = 0.010
# Episode 1630 | Reward = -1052.69 | Epsilon = 0.010
# Episode 1640 | Reward = -1067.39 | Epsilon = 0.010
# Episode 1650 | Reward = -1184.42 | Epsilon = 0.010
# Episode 1660 | Reward = -989.50 | Epsilon = 0.010
# Episode 1670 | Reward = -1128.06 | Epsilon = 0.010
# Episode 1680 | Reward = -953.75 | Epsilon = 0.010
# Episode 1690 | Reward = -1055.37 | Epsilon = 0.010
# Episode 1700 | Reward = -1063.24 | Epsilon = 0.010
# Episode 1710 | Reward = -904.53 | Epsilon = 0.010
# Episode 1720 | Reward = -993.98 | Epsilon = 0.010
# Episode 1730 | Reward = -1046.14 | Epsilon = 0.010
# Episode 1740 | Reward = -930.55 | Epsilon = 0.010
# Episode 1750 | Reward = -968.20 | Epsilon = 0.010
# Episode 1760 | Reward = -917.92 | Epsilon = 0.010
# Episode 1770 | Reward = -919.84 | Epsilon = 0.010
# Episode 1780 | Reward = -916.97 | Epsilon = 0.010
# Episode 1790 | Reward = -763.32 | Epsilon = 0.010
# Episode 1800 | Reward = -939.75 | Epsilon = 0.010
# Episode 1810 | Reward = -1060.98 | Epsilon = 0.010
# Episode 1820 | Reward = -881.26 | Epsilon = 0.010
# Episode 1830 | Reward = -964.05 | Epsilon = 0.010
# Episode 1840 | Reward = -943.80 | Epsilon = 0.010
# Episode 1850 | Reward = -896.76 | Epsilon = 0.010
# Episode 1860 | Reward = -1024.23 | Epsilon = 0.010
# Episode 1870 | Reward = -942.51 | Epsilon = 0.010
# Episode 1880 | Reward = -1022.72 | Epsilon = 0.010
# Episode 1890 | Reward = -907.90 | Epsilon = 0.010
# Episode 1900 | Reward = -919.06 | Epsilon = 0.010
# Episode 1910 | Reward = -939.80 | Epsilon = 0.010
# Episode 1920 | Reward = -926.77 | Epsilon = 0.010
# Episode 1930 | Reward = -911.45 | Epsilon = 0.010
# Episode 1940 | Reward = -933.30 | Epsilon = 0.010
# Episode 1950 | Reward = -938.85 | Epsilon = 0.010
# Episode 1960 | Reward = -956.09 | Epsilon = 0.010
# Episode 1970 | Reward = -882.91 | Epsilon = 0.010
# Episode 1980 | Reward = -944.04 | Epsilon = 0.010
# Episode 1990 | Reward = -977.31 | Epsilon = 0.010
# Episode 2000 | Reward = -1006.33 | Epsilon = 0.010
# Episode 2010 | Reward = -972.88 | Epsilon = 0.010
# Episode 2020 | Reward = -995.06 | Epsilon = 0.010
# Episode 2030 | Reward = -942.56 | Epsilon = 0.010
# Episode 2040 | Reward = -901.12 | Epsilon = 0.010
# Episode 2050 | Reward = -1062.05 | Epsilon = 0.010
# Episode 2060 | Reward = -929.24 | Epsilon = 0.010
# Episode 2070 | Reward = -988.45 | Epsilon = 0.010
# Episode 2080 | Reward = -931.17 | Epsilon = 0.010
# Episode 2090 | Reward = -958.29 | Epsilon = 0.010
# Episode 2100 | Reward = -971.92 | Epsilon = 0.010
# Episode 2110 | Reward = -1041.03 | Epsilon = 0.010
# Episode 2120 | Reward = -962.04 | Epsilon = 0.010
# Episode 2130 | Reward = -1263.51 | Epsilon = 0.010
# Episode 2140 | Reward = -981.86 | Epsilon = 0.010
# Episode 2150 | Reward = -921.92 | Epsilon = 0.010
# Episode 2160 | Reward = -869.62 | Epsilon = 0.010
# Episode 2170 | Reward = -1170.35 | Epsilon = 0.010
# Episode 2180 | Reward = -956.05 | Epsilon = 0.010
# Episode 2190 | Reward = -1002.56 | Epsilon = 0.010
# Episode 2200 | Reward = -942.40 | Epsilon = 0.010
# Episode 2210 | Reward = -1009.40 | Epsilon = 0.010
# Episode 2220 | Reward = -977.49 | Epsilon = 0.010
# Episode 2230 | Reward = -955.61 | Epsilon = 0.010
# Episode 2240 | Reward = -923.26 | Epsilon = 0.010
# Episode 2250 | Reward = -924.44 | Epsilon = 0.010
# Episode 2260 | Reward = -897.53 | Epsilon = 0.010
# Episode 2270 | Reward = -982.19 | Epsilon = 0.010
# Episode 2280 | Reward = -930.88 | Epsilon = 0.010
# Episode 2290 | Reward = -913.51 | Epsilon = 0.010
# Episode 2300 | Reward = -929.98 | Epsilon = 0.010
# Episode 2310 | Reward = -952.25 | Epsilon = 0.010
# Episode 2320 | Reward = -1014.69 | Epsilon = 0.010
# Episode 2330 | Reward = -907.97 | Epsilon = 0.010
# Episode 2340 | Reward = -1011.52 | Epsilon = 0.010
# Episode 2350 | Reward = -937.87 | Epsilon = 0.010
# Episode 2360 | Reward = -927.33 | Epsilon = 0.010
# Episode 2370 | Reward = -904.36 | Epsilon = 0.010
# Episode 2380 | Reward = -1019.41 | Epsilon = 0.010
# Episode 2390 | Reward = -1192.28 | Epsilon = 0.010
# Episode 2400 | Reward = -956.55 | Epsilon = 0.010
# Episode 2410 | Reward = -928.52 | Epsilon = 0.010
# Episode 2420 | Reward = -970.14 | Epsilon = 0.010
# Episode 2430 | Reward = -881.39 | Epsilon = 0.010
# Episode 2440 | Reward = -964.59 | Epsilon = 0.010
# Episode 2450 | Reward = -945.72 | Epsilon = 0.010
# Episode 2460 | Reward = -987.04 | Epsilon = 0.010
# Episode 2470 | Reward = -969.60 | Epsilon = 0.010
# Episode 2480 | Reward = -1242.85 | Epsilon = 0.010
# Episode 2490 | Reward = -1127.33 | Epsilon = 0.010
# Episode 2500 | Reward = -919.65 | Epsilon = 0.010
# Episode 2510 | Reward = -1036.98 | Epsilon = 0.010
# Episode 2520 | Reward = -1046.81 | Epsilon = 0.010
# Episode 2530 | Reward = -988.38 | Epsilon = 0.010
# Episode 2540 | Reward = -971.45 | Epsilon = 0.010
# Episode 2550 | Reward = -1076.22 | Epsilon = 0.010
# Episode 2560 | Reward = -901.91 | Epsilon = 0.010
# Episode 2570 | Reward = -1611.11 | Epsilon = 0.010
# Episode 2580 | Reward = -935.66 | Epsilon = 0.010
# Episode 2590 | Reward = -1137.77 | Epsilon = 0.010
# Episode 2600 | Reward = -883.01 | Epsilon = 0.010
# Episode 2610 | Reward = -972.25 | Epsilon = 0.010
# Episode 2620 | Reward = -946.60 | Epsilon = 0.010
# Episode 2630 | Reward = -889.45 | Epsilon = 0.010
# Episode 2640 | Reward = -944.80 | Epsilon = 0.010
# Episode 2650 | Reward = -889.36 | Epsilon = 0.010
# Episode 2660 | Reward = -914.59 | Epsilon = 0.010
# Episode 2670 | Reward = -884.79 | Epsilon = 0.010
# Episode 2680 | Reward = -968.80 | Epsilon = 0.010
# Episode 2690 | Reward = -1546.00 | Epsilon = 0.010
# Episode 2700 | Reward = -921.32 | Epsilon = 0.010
# Episode 2710 | Reward = -955.68 | Epsilon = 0.010
# Episode 2720 | Reward = -939.49 | Epsilon = 0.010
# Episode 2730 | Reward = -976.58 | Epsilon = 0.010
# Episode 2740 | Reward = -975.35 | Epsilon = 0.010
# Episode 2750 | Reward = -947.59 | Epsilon = 0.010
# Episode 2760 | Reward = -1051.37 | Epsilon = 0.010
# Episode 2770 | Reward = -893.55 | Epsilon = 0.010
# Episode 2780 | Reward = -881.45 | Epsilon = 0.010
# Episode 2790 | Reward = -958.61 | Epsilon = 0.010
# Episode 2800 | Reward = -880.06 | Epsilon = 0.010
# Episode 2810 | Reward = -1264.74 | Epsilon = 0.010
# Episode 2820 | Reward = -1077.18 | Epsilon = 0.010
# Episode 2830 | Reward = -1064.00 | Epsilon = 0.010
# Episode 2840 | Reward = -967.41 | Epsilon = 0.010
# Episode 2850 | Reward = -969.74 | Epsilon = 0.010
# Episode 2860 | Reward = -981.16 | Epsilon = 0.010
# Episode 2870 | Reward = -1040.94 | Epsilon = 0.010
# Episode 2880 | Reward = -890.80 | Epsilon = 0.010
# Episode 2890 | Reward = -933.62 | Epsilon = 0.010
# Episode 2900 | Reward = -945.00 | Epsilon = 0.010
# Episode 2910 | Reward = -895.38 | Epsilon = 0.010
# Episode 2920 | Reward = -945.95 | Epsilon = 0.010
# Episode 2930 | Reward = -1054.24 | Epsilon = 0.010
# Episode 2940 | Reward = -1010.99 | Epsilon = 0.010
# Episode 2950 | Reward = -925.57 | Epsilon = 0.010
# Episode 2960 | Reward = -904.55 | Epsilon = 0.010
# Episode 2970 | Reward = -940.61 | Epsilon = 0.010
# Episode 2980 | Reward = -946.62 | Epsilon = 0.010
# Episode 2990 | Reward = -1059.32 | Epsilon = 0.010

# %%
# TRAINING PERFORMANCE

plt.figure(figsize=(10,5))

plt.plot(reward_history)

plt.xlabel("Episode")
plt.ylabel("Total Reward")

plt.title("DQN Training Progress")

plt.grid()

plt.show()

# %%
# DQN-CONTROLLED SIMULATION

epsilon = 0.0

m_dot = 0.50
T_hot_in = 80.0

# Logging
T_log = []
m_log = []
dP_log = []
Tin_log = []
time_log = []

# %%
# CLOSED-LOOP CONTROL TEST

for step in range(200):

    # Disturbance
    if step > 100:
        T_hot_in = 70.0

    # Current state
    T_out = hx_model(
        m_dot,
        T_hot_in
    )

    dP = pressure_drop(
        m_dot
    )

    state = get_state(
        T_out,
        m_dot,
        T_hot_in
    )

    # Neural network chooses action
    state_tensor = torch.FloatTensor(
        state
    ).unsqueeze(0).to(device)

    with torch.no_grad():

        q_values = model(state_tensor)

    action_index = torch.argmax(
        q_values
    ).item()

    action = actions[action_index]

    # Apply action
    m_dot = m_dot + action

    m_dot = np.clip(
        m_dot,
        0.05,
        1.0
    )

    # Logging
    T_log.append(T_out)
    m_log.append(m_dot)
    dP_log.append(dP)
    Tin_log.append(T_hot_in)
    time_log.append(step)

# %%
# TEMPERATURE RESPONSE

plt.figure(figsize=(12,6))

plt.plot(
    time_log,
    T_log,
    linewidth=2,
    label="DQN Temperature"
)

plt.axhline(
    T_target,
    linestyle='--',
    linewidth=2,
    label="Target Temperature"
)

plt.xlabel("Time Step")
plt.ylabel("Temperature (°C)")

plt.title("DQN-Controlled Heat Exchanger")

plt.legend()

plt.grid()

plt.show()

# %%
# CONTROL ACTIONS

plt.figure(figsize=(12,6))

plt.plot(
    time_log,
    m_log,
    linewidth=2
)

plt.xlabel("Time Step")
plt.ylabel("Mass Flow Rate (kg/s)")

plt.title("DQN Control Actions")

plt.grid()

plt.show()

# %%
# PRESSURE DROP

plt.figure(figsize=(12,6))

plt.plot(
    time_log,
    dP_log,
    linewidth=2
)

plt.xlabel("Time Step")
plt.ylabel("Pressure Drop (Pa)")

plt.title("Pressure Drop During DQN Control")

plt.grid()

plt.show()

# %%
# DISTURBANCE PROFILE

plt.figure(figsize=(12,6))

plt.plot(
    time_log,
    Tin_log,
    linewidth=2
)

plt.xlabel("Time Step")
plt.ylabel("Hot Inlet Temperature (°C)")

plt.title("Disturbance Input")

plt.grid()

plt.show()

# %%
#saving a model
torch.save(model.state_dict(), 'model.pth')
